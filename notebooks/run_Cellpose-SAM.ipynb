# %% [markdown]
# <a href="https://colab.research.google.com/github/Kian-Oosterbeek-KO/Cell-fate-analysis-based-on-size/blob/main/notebooks/run_Cellpose-SAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Cellpose-SAM: superhuman generalization for cellular segmentation
#
# Marius Pachitariu, Michael Rariden, Carsen Stringer
#
# [paper](https://www.biorxiv.org/content/10.1101/2025.04.28.651001v1) | [code](https://github.com/MouseLand/cellpose)
#
# This notebook shows how to process your own 2D or 3D images, saved on Google Drive.
#
# This notebook is adapted from the notebook by Pradeep Rajasekhar, inspired by the [ZeroCostDL4Mic notebook series](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki).

# %% [markdown]
# ### Make sure you have GPU access enabled by going to Runtime -> Change Runtime Type -> Hardware accelerator and selecting GPU
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Mount your google drive
#
# Run this cell to connect your Google Drive to colab:
# * Click on the URL.
# * Sign in your Google Account.
#
# You will either have to:
# * copy the authorisation code and enter it into box below OR
# * in the new google colab, you can just click "Allow" and it should connect.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Then click on "Folder" icon on the Left, press the refresh button. Your Google Drive folder should now be available here as "gdrive".
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Click on the triangle icon and it will allow you to access whole drive. Navigate to the folder containing your images. Once you are there, click on the three dots on the right of the folder and select "Copy Path"
#
# ![image.png](data:image/png;base64,...)
#
# Copy and paste this path in the **dir** string below

# %% [markdown]
# ### Install Cellpose-SAM

# %%
# !pip install git+https://www.github.com/mouseland/cellpose.git
# Out:
# Collecting git+https://www.github.com/mouseland/cellpose.git
#   Cloning https://www.github.com/mouseland/cellpose.git to /tmp/pip-req-build-6sxa6etj
#   Running command git clone --filter=blob:none --quiet https://www.github.com/mouseland/cellpose.git /tmp/pip-req-build-6sxa6etj
#   warning: redirecting to https://github.com/mouseland/cellpose.git/
#   Resolved https://www.github.com/mouseland/cellpose.git to commit a9f8bfcde43033247309e3982747df9fe9f09315
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from cellpose==4.1.1) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from cellpose==4.1.1) (1.16.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from cellpose==4.1.1) (8.4.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from cellpose==4.1.1) (2026.3.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cellpose==4.1.1) (4.67.3)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from cellpose==4.1.1) (0.25.0+cu128)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from cellpose==4.1.1) (4.13.0.92)
# Collecting fastremap (from cellpose==4.1.1)
#   Downloading fastremap-1.18.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting imagecodecs (from cellpose==4.1.1)
#   Downloading imagecodecs-2026.3.6-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (21 kB)
# Collecting roifile (from cellpose==4.1.1)
#   Downloading roifile-2026.2.10-py3-none-any.whl.metadata (6.0 kB)
# Collecting fill-voids (from cellpose==4.1.1)
#   Downloading fill_voids-2.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting segment_anything (from cellpose==4.1.1)
#   Downloading segment_anything-1.0-py3-none-any.whl.metadata (487 bytes)
# Requirement already satisfied: torch==2.10.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->cellpose==4.1.1) (2.10.0+cu128)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->cellpose==4.1.1) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->cellpose==4.1.1) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch==2.10.0->torchvision->cellpose==4.1.1) (1.5.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.10.0->torchvision->cellpose==4.1.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.10.0->torchvision->cellpose==4.1.1) (3.0.3)
# Downloading fastremap-1.18.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 91.5 MB/s eta 0:00:00
# Downloading fill_voids-2.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 86.9 MB/s eta 0:00:00
# Downloading imagecodecs-2026.3.6-cp311-abi3-manylinux_2_28_x86_64.whl (26.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 80.8 MB/s eta 0:00:00
# Downloading roifile-2026.2.10-py3-none-any.whl (21 kB)
# Downloading segment_anything-1.0-py3-none-any.whl (36 kB)
# Building wheels for collected packages: cellpose
#   Building wheel for cellpose (setup.py) ... done
#   Created wheel for cellpose: filename=cellpose-4.1.1-py3-none-any.whl size=213288 sha256=cbd885eb8b58f465075515a4628d2d5fa0ba320f48657187d696760ebe75edf4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m7n4fb0x/wheels/df/b6/31/a3013c44290eabb46f4c06d1efb19744124fcad2d59684ec5e
# Successfully built cellpose
# Installing collected packages: segment_anything, roifile, imagecodecs, fastremap, fill-voids, cellpose
# Successfully installed cellpose-4.1.1 fastremap-1.18.0 fill-voids-2.1.1 imagecodecs-2026.3.6 roifile-2026.2.10 segment_anything-1.0

# %% [markdown]
# Check GPU and instantiate model - will download weights.

# %%
import numpy as np
from cellpose import models, core, io, plot
from pathlib import Path
from tqdm import trange
import matplotlib.pyplot as plt
from natsort import natsorted

io.logger_setup() # run this to get printing of progress

#Check if colab notebook instance has GPU access
if core.use_gpu()==False:
  raise ImportError("No GPU access, change your runtime")

model = models.CellposeModel(gpu=True)
# Out:
# creating new log file
# 2026-04-17 08:46:21,095 [INFO] WRITING LOG OUTPUT TO /root/.cellpose/run.log
# 2026-04-17 08:46:21,096 [INFO]
# cellpose version: 	4.1.1
# platform:       	linux
# python version: 	3.12.13
# torch version:  	2.10.0+cu128
# 2026-04-17 08:46:21,498 [INFO] ** TORCH CUDA version installed and working. **
# 2026-04-17 08:46:21,499 [INFO] ** TORCH CUDA version installed and working. **
# 2026-04-17 08:46:21,501 [INFO] >>>> using GPU (CUDA)
# 2026-04-17 08:46:23,929 [INFO] Downloading: "https://huggingface.co/mouseland/cellpose-sam/resolve/main/cpsam" to /root/.cellpose/models/cpsam
# 100%|██████████| 1.15G/1.15G [00:04<00:00, 249MB/s]

# %% [markdown]
# Input directory with your images:

# %%
# *** change to your google drive folder path ***
dir = "/content/drive/MyDrive/Image analysis/KO011_cell death/KO011 0h_tiff_files"
dir = Path(dir)
if not dir.exists():
  raise FileNotFoundError("directory does not exist")

# *** change to your image extension ***
image_ext = ".tiff"

# list all files
files = natsorted([f for f in dir.glob("*"+image_ext) if "_masks" not in f.name and "_flows" not in f.name])

if(len(files)==0):
  raise FileNotFoundError("no image files found, did you specify the correct folder and extension?")
else:
  print(f"{len(files)} images in folder:")

for f in files:
  print(f.name)
# Out:
# 4 images in folder:
# PC-9 0h ic50 5x.tiff
# PC-9 0h ic50 10x.tiff
# PC-9 0h ic50 40x.tiff
# PC-9 0h ic90 5x.tiff

# %% [markdown]
# ## Run Cellpose-SAM on one image in folder
#
# Here are some of the parameters you can change:
#
# * ***flow_threshold*** is  the  maximum  allowed  error  of  the  flows  for  each  mask.   The  default  is 0.4.
#     *  **Increase** this threshold if cellpose is not returning as many masks as you’d expect (or turn off completely with 0.0)
#     *   **Decrease** this threshold if cellpose is returning too many ill-shaped masks.
#
# * ***cellprob_threshold*** determines proability that a detected object is a cell.   The  default  is 0.0.
#     *   **Decrease** this threshold if cellpose is not returning as many masks as you’d expect or if masks are too small
#     *   **Increase** this threshold if cellpose is returning too many masks esp from dull/dim areas.
#
# * ***tile_norm_blocksize*** determines the size of blocks used for normalizing the image. The default is 0, which means the entire image is normalized together.
#   You may want to change this to 100-200 pixels if you have very inhomogeneous brightness across your image.

# %%
img = io.imread(files[0])

print(f'your image has shape: {img.shape}. Assuming channel dimension is last with {img.shape[-1]} channels')
# Out:
# your image has shape: (1080, 1920, 4). Assuming channel dimension is last with 4 channels

# %% [markdown]
# ### Channel Selection:
#
# - Use the dropdowns below to select the _zero-indexed_ channels of your image to segment. The order does not matter. Remember to rerun the cell after you edit the dropdowns.
#
# - If you have a histological image taken in brightfield, you don't need to adjust the channels.
#
# - If you have a fluroescent image with multiple stains, you should choose one channel with a cytoplasm/membrane stain, one channel with a nuclear stain, and set the third channel to `None`. Choosing multiple channels may produce segmentaiton of all the structures in the image. If you have retrained the model on your data with a thrid stain (described below), you can run segmentation with all channels.

# %%
first_channel = '0' # @param ['None', 0, 1, 2, 3, 4, 5]
second_channel = '1' # @param ['None', 0, 1, 2, 3, 4, 5]
third_channel = '2' # @param ['None', 0, 1, 2, 3, 4, 5]

# %%
selected_channels = []
for i, c in enumerate([first_channel, second_channel, third_channel]):
  if c == 'None':
    continue
  if int(c) > img.shape[-1]:
    assert False, 'invalid channel index, must have index greater or equal to the number of channels'
  if c != 'None':
    selected_channels.append(int(c))



img_selected_channels = np.zeros_like(img)
img_selected_channels[:, :, :len(selected_channels)] = img[:, :, selected_channels]


flow_threshold = 0.4
cellprob_threshold = 0.0
tile_norm_blocksize = 0

masks, flows, styles = model.eval(img_selected_channels, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

fig = plt.figure(figsize=(12,5))
plot.show_segmentation(fig, img_selected_channels[:, :, :3], masks, flows[0])
plt.tight_layout()
plt.show()
# Out:
# 2026-04-17 08:48:15,608 [WARNING] Found more than 3 channels, only using first 3

# %% [markdown]
# ## Run Cellpose-SAM on folder of images
#
# if you have many large images, you may want to run them as a loop over images

# %%
masks_ext = ".png" if image_ext == ".png" else ".tif"
for i in trange(len(files)):
    f = files[i]
    img = io.imread(f)
    masks, flows, styles = model.eval(img, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# 2026-04-17 08:49:05,319 [WARNING] Found more than 3 channels, only using first 3
#  25%|██▌       | 1/4 [00:21<01:05, 21.86s/it]
# 2026-04-17 08:49:27,860 [WARNING] Found more than 3 channels, only using first 3
#  50%|█████     | 2/4 [00:46<00:46, 23.41s/it]
# 2026-04-17 08:49:52,274 [WARNING] Found more than 3 channels, only using first 3
#  75%|███████▌  | 3/4 [01:11<00:24, 24.33s/it]
# 2026-04-17 08:50:17,729 [WARNING] Found more than 3 channels, only using first 3
# 100%|██████████| 4/4 [01:35<00:00, 23.93s/it]

# %% [markdown]
# if you have small images, you may want to load all of them first and then run, so that they can be batched together on the GPU

# %%
print("loading images")
imgs = [io.imread(files[i]) for i in trange(len(files))]

print("running cellpose-SAM")
masks, flows, styles = model.eval(imgs, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

print("saving masks")
for i in trange(len(files)):
    f = files[i]
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks[i])
# Out:
# loading images
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1659/2544379586.py in <cell line: 0>()
#       1 print("loading images")
# ----> 2 imgs = [io.imread(files[i]) for i in trange(len(files))]
#       3
#       4 print("running cellpose-SAM")
#       5 masks, flows, styles = model.eval(imgs, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
#
# NameError: name 'trange' is not defined

# %% [markdown]
# to save your masks for ImageJ, run the following code:

# %%
for i in trange(len(files)):
    f = files[i]
    masks0 = io.imsave(dir / (f.name + "_masks" + masks_ext))
    io.save_rois(masks0, f)
